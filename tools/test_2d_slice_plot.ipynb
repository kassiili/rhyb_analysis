# %%
import cProfile
from rhybrid_2d_slice_plot import main

# %% [markdown]
# ## Profiling

# %%
plot_cfg_path = ["/home/kassiili/rhyb/rhyb_analysis/tools/config_2d_slice_plot/mars_example.toml"]

# %%
cProfile.run('main(plot_cfg_path, n_cores=1)')

# To write output into file:
# cProfile.run('main(plot_cfg_path, n_cores=1)', "profiling/rhybrid_2d_slice_plot.out")

# %%
cProfile.run('main(plot_cfg_path, n_cores=4)')
# Out:
# Files found: 11
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 800 | cellB magnitude
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 400 | cellB magnitude
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 0 | cellB magnitude
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 1200 | cellB magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 0 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 800 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 400 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 0 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 1200 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 0 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 800 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 400 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 1200 | v_H+sw_ave magnitude
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 1600 | cellB magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 800 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 1200 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 400 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 1600 | n_H+sw_ave scalar
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 1600 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2000 | cellB magnitude
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2400 | cellB magnitude
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2800 | cellB magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2000 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 1600 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2400 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2800 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2000 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2800 | v_H+sw_ave magnitude
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 3200 | cellB magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2400 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2000 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2800 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 2400 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 3200 | n_H+sw_ave scalar
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 3600 | cellB magnitude
# Files found: 11
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 4000 | cellB magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 3200 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 4000 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 3600 | n_H+sw_ave scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 3200 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 3600 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 4000 | v_H+sw_ave magnitude
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 3600 | T_H+sw scalar
# (hostname = lx5-500-35006.ad.helsinki.fi) sim_data | step 4000 | T_H+sw scalar
